# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import json
import csv
import pandas as pd

# %%
data = pd.read_csv("cleaned_tags_data.csv")

# %%
import json
import csv
import pandas as pd

# Load JSON data
with open('books_data_updated.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Function to rename tags
def rename_tags(data):
    for book in data.get('books', []):
        if 'tags' in book and isinstance(book['tags'], list):
            for tag in book['tags']:
                if isinstance(tag, dict) and tag.get('tag') == 'Supernatural Fiction':
                    tag['tag'] = 'Supernatural'  # Rename tag
    return data

# Apply tag renaming
data = rename_tags(data)

# Save updated data to CSV
csv_file_path = 'updated_books_data.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['id', 'title', 'author', 'genre', 'rating', 'releaseDate', 'pages', 'description', 'tags']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    
    for book in data.get('books', []):
        book_info = {
            'id': book.get('id', ''),
            'title': book.get('title', ''),
            'author': book.get('author', ''),
            'genre': book.get('genre', ''),
            'rating': book.get('rating', ''),
            'releaseDate': book.get('releaseDate', ''),
            'pages': book.get('pages', ''),
            'description': book.get('description', '')
        }
        
        tags = ', '.join([tag['tag'] for tag in book.get('tags', []) if isinstance(tag, dict)])
        book_info['tags'] = tags

        writer.writerow(book_info)

print(f"Updated books data has been successfully saved to {csv_file_path}.")

# Load CSV for tag aggregation
df = pd.read_csv(csv_file_path)

# Aggregate unique tags for each genre
genre_tags = {}
for _, row in df.iterrows():
    genre = row['genre']
    tags = str(row['tags']).split(', ')
    if genre not in genre_tags:
        genre_tags[genre] = set()
    genre_tags[genre].update(tags)

# Convert to DataFrame and save to CSV
unique_genre_tags_df = pd.DataFrame([
    {'genre': genre, 'tags': ', '.join(tags)} for genre, tags in genre_tags.items()
])

unique_genre_tags_df.to_csv('updated_genre_tags.csv', index=False, encoding='utf-8')

print("Unique genre tags have been saved to updated_genre_tags.csv.")
# Out:
# Updated books data has been successfully saved to updated_books_data.csv.
# Unique genre tags have been saved to updated_genre_tags.csv.

# %%
import json
import csv
import pandas as pd

# Load JSON data
with open('books_data_updated.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Define specific tag-to-genre mappings
tag_genre_mapping = {
    'Supernatural': 'Fantasy' ,
     'Missing persons': 'Mystery' # Change genre to Fantasy if tag is Supernatural
}

# Function to reassign genre based on specific tags
def reassign_genre(data, tag_genre_mapping):
    for book in data.get('books', []):
        if 'tags' in book and isinstance(book['tags'], list):
            for tag in book['tags']:
                if tag.get('tag') in tag_genre_mapping:  # Check if tag matches
                    book['genre'] = tag_genre_mapping[tag['tag']]  # Update genre
                    print(f"Updated genre of book '{book['title']}' to '{book['genre']}' due to tag '{tag['tag']}'")
                    break  # Stop after the first match to prevent multiple updates
    return data

# Apply genre reassignment
data = reassign_genre(data, tag_genre_mapping)

# Save updated JSON
with open('new_books_data_updated.json', 'w', encoding='utf-8') as file:
    json.dump(data, file, indent=4)

print("Genres updated successfully!")

# Save updated data to CSV
csv_file_path = 'new_updated_data.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['id', 'title', 'author', 'genre', 'rating', 'releaseDate', 'pages', 'description', 'tags']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    
    for book in data.get('books', []):
        book_info = {
            'id': book.get('id', ''),
            'title': book.get('title', ''),
            'author': book.get('author', ''),
            'genre': book.get('genre', ''),
            'rating': book.get('rating', ''),
            'releaseDate': book.get('releaseDate', ''),
            'pages': book.get('pages', ''),
            'description': book.get('description', '')
        }
        
        tags = ', '.join([tag['tag'] for tag in book.get('tags', []) if isinstance(tag, dict)])
        book_info['tags'] = tags

        writer.writerow(book_info)

print(f"Cleaned books data has been successfully saved to {csv_file_path}.")

# Load CSV for tag aggregation
df = pd.read_csv(csv_file_path)

# Aggregate unique tags for each genre
genre_tags = {}
for _, row in df.iterrows():
    genre = row['genre']
    tags = str(row['tags']).split(', ')
    if genre not in genre_tags:
        genre_tags[genre] = set()
    genre_tags[genre].update(tags)

# Convert to DataFrame and save to CSV
unique_genre_tags_df = pd.DataFrame([
    {'genre': genre, 'tags': ', '.join(tags)} for genre, tags in genre_tags.items()
])

unique_genre_tags_df.to_csv('updated_genre_tags.csv', index=False, encoding='utf-8')

print("Unique genre tags have been saved to updated_genre_tags.csv.")
# Out:
# Updated genre of book 'Needful Things' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Pretty Girls' to 'Mystery' due to tag 'Missing persons'
# Updated genre of book 'My Best Friend's Exorcism' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'The Turn Of The Screw' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Anya's Ghost' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'She Who Became the Sun' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Lovecraft Country' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Lapvona' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'The Devil Takes You Home' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Rouge' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Lone Women' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Nineteen Claws and a Black Bird: Stories' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Diavola' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Incidents Around the House' to 'Fantasy' due to tag 'Supernatural'
# Genres updated successfully!
# Cleaned books data has been successfully saved to new_updated_data.csv.
# Unique genre tags have been saved to updated_genre_tags.csv.

# %%
import json

# Load JSON data
with open('books_data_updated.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Define tag renaming mapping
tag_rename_mapping = {
    'Supernatural Fiction': 'Supernatural',
    'Paranormal Fiction': 'Paranormal',
}

# Function to rename tags across all genres
def rename_tags(data, tag_rename_mapping):
    for book in data.get('books', []):
        if 'tags' in book and isinstance(book['tags'], list):
            for tag in book['tags']:
                if tag.get('tag') in tag_rename_mapping:  # Check if the tag matches the mapping
                    old_tag = tag['tag']
                    tag['tag'] = tag_rename_mapping[old_tag]  # Rename the tag
                    print(f"Renamed tag '{old_tag}' to '{tag['tag']}' in book '{book['title']}'")
    return data

# Apply tag renaming
data = rename_tags(data, tag_rename_mapping)

# Save updated JSON
with open('new_books_data_updated.json', 'w', encoding='utf-8') as file:
    json.dump(data, file, indent=4)

print("Tags renamed successfully!")
# Out:
# Renamed tag 'Supernatural Fiction' to 'Supernatural' in book 'Horrorstör'
# Renamed tag 'Supernatural Fiction' to 'Supernatural' in book 'Slewfoot: A Tale of Bewitchery'
# Renamed tag 'Supernatural Fiction' to 'Supernatural' in book 'How to Sell a Haunted House'
# Renamed tag 'Supernatural Fiction' to 'Supernatural' in book 'Camp Damascus'
# Renamed tag 'Supernatural Fiction' to 'Supernatural' in book 'Bride'
# Tags renamed successfully!

# %%
# Save updated data to CSV
csv_file_path = 'new_updated_data.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['id', 'title', 'author', 'genre', 'rating', 'releaseDate', 'pages', 'description', 'tags']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    
    for book in data.get('books', []):
        book_info = {
            'id': book.get('id', ''),
            'title': book.get('title', ''),
            'author': book.get('author', ''),
            'genre': book.get('genre', ''),
            'rating': book.get('rating', ''),
            'releaseDate': book.get('releaseDate', ''),
            'pages': book.get('pages', ''),
            'description': book.get('description', '')
        }
        
        tags = ', '.join([tag['tag'] for tag in book.get('tags', []) if isinstance(tag, dict)])
        book_info['tags'] = tags

        writer.writerow(book_info)

print(f"Cleaned books data has been successfully saved to {csv_file_path}.")

# Load CSV for tag aggregation
df = pd.read_csv(csv_file_path)

# Aggregate unique tags for each genre
genre_tags = {}
for _, row in df.iterrows():
    genre = row['genre']
    tags = str(row['tags']).split(', ')
    if genre not in genre_tags:
        genre_tags[genre] = set()
    genre_tags[genre].update(tags)

# Convert to DataFrame and save to CSV
unique_genre_tags_df = pd.DataFrame([
    {'genre': genre, 'tags': ', '.join(tags)} for genre, tags in genre_tags.items()
])

unique_genre_tags_df.to_csv('New_updated_genre_tags.csv', index=False, encoding='utf-8')

print("Unique genre tags have been saved to updated_genre_tags.csv.")
# Out:
# Cleaned books data has been successfully saved to new_updated_data.csv.
# Unique genre tags have been saved to updated_genre_tags.csv.

# %%
# Load JSON data
with open('books_data_updated.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Dictionary for tag renaming
tag_renaming_map = {
    'Supernatural Fiction': 'Supernatural',
    'Adaptability (Psychology)': 'Psychology',
    'Identity (Psychology)':'Psychology',
    'Change (Psychology)': 'Psychology',
    'Control (Psychology)': 'Psychology',
    'Self-management (Psychology)': 'Psychology',
    'Archetype (Psychology)': 'Archetype',
    'psychological thriller' : 'Psychological thriller',
    'Assertiveness (Psychology)': 'Psychology',
    'psychological horror': 'Psychological thriller',
    'Self-actualization (Psychology)': 'Psychology',
    'Adult children of dysfunctional families': 'Trauma',
    'Fantasy Fiction': 'Fantasy',
    'Horror Fiction': 'Horror'
    # Add more mappings as needed
}

# Function to rename tags
def rename_tags(data, tag_renaming_map):
    for book in data.get('books', []):
        if 'tags' in book and isinstance(book['tags'], list):
            for tag in book['tags']:
                if isinstance(tag, dict) and tag.get('tag') in tag_renaming_map:
                    tag['tag'] = tag_renaming_map[tag['tag']]  # Rename tag
    return data

# Apply tag renaming
data = rename_tags(data, tag_renaming_map)

# Save updated data to CSV
csv_file_path = 'updated_books_data.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['id', 'title', 'author', 'genre', 'rating', 'releaseDate', 'pages', 'description', 'tags']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    
    for book in data.get('books', []):
        book_info = {
            'id': book.get('id', ''),
            'title': book.get('title', ''),
            'author': book.get('author', ''),
            'genre': book.get('genre', ''),
            'rating': book.get('rating', ''),
            'releaseDate': book.get('releaseDate', ''),
            'pages': book.get('pages', ''),
            'description': book.get('description', '')
        }
        
        tags = ', '.join([tag['tag'] for tag in book.get('tags', []) if isinstance(tag, dict)])
        book_info['tags'] = tags

        writer.writerow(book_info)

print(f"Step 1: Updated books data has been successfully saved to {csv_file_path}.")



### Step 2: Reassign genres based on specific tags and generate new CSVs ###

# Define specific tag-to-genre mappings
tag_genre_mapping = {
    'Supernatural': 'Fantasy',
    'Missing persons': 'Mystery',
    'Memoir': 'Biography & Autobiography',
    'Magical Realism': 'Fantasy'
}

# Function to reassign genre based on specific tags
def reassign_genre(data, tag_genre_mapping):
    for book in data.get('books', []):
        if 'tags' in book and isinstance(book['tags'], list):
            for tag in book['tags']:
                if tag.get('tag') in tag_genre_mapping:  # Check if tag matches
                    book['genre'] = tag_genre_mapping[tag['tag']]  # Update genre
                    print(f"Updated genre of book '{book['title']}' to '{book['genre']}' due to tag '{tag['tag']}'")
                    break  # Stop after the first match to prevent multiple updates
    return data

# Apply genre reassignment
data = reassign_genre(data, tag_genre_mapping)

# Save updated JSON
with open('new_books_data_updated.json', 'w', encoding='utf-8') as file:
    json.dump(data, file, indent=4)

print("Step 2: Genres updated successfully!")

# Save updated data to CSV
csv_file_path = 'new_updated_data.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['id', 'title', 'author', 'genre', 'rating', 'releaseDate', 'pages', 'description', 'tags']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    
    for book in data.get('books', []):
        book_info = {
            'id': book.get('id', ''),
            'title': book.get('title', ''),
            'author': book.get('author', ''),
            'genre': book.get('genre', ''),
            'rating': book.get('rating', ''),
            'releaseDate': book.get('releaseDate', ''),
            'pages': book.get('pages', ''),
            'description': book.get('description', '')
        }
        
        tags = ', '.join([tag['tag'] for tag in book.get('tags', []) if isinstance(tag, dict)])
        book_info['tags'] = tags

        writer.writerow(book_info)

print(f"Step 2: Cleaned books data has been successfully saved to {csv_file_path}.")

# Load CSV for tag aggregation
df = pd.read_csv(csv_file_path)

# Aggregate unique tags for each genre
genre_tags = {}
for _, row in df.iterrows():
    genre = row['genre']
    tags = str(row['tags']).split(', ')
    if genre not in genre_tags:
        genre_tags[genre] = set()
    genre_tags[genre].update(tags)

# Convert to DataFrame and save to CSV
unique_genre_tags_df = pd.DataFrame([
    {'genre': genre, 'tags': ', '.join(tags)} for genre, tags in genre_tags.items()
])

unique_genre_tags_df.to_csv('final_updated_genre_tags.csv', index=False, encoding='utf-8')

print("Step 2: Unique genre tags have been saved to final_updated_genre_tags.csv.")
# Out:
# Step 1: Updated books data has been successfully saved to updated_books_data.csv.
# Updated genre of book 'Needful Things' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'The Satanic Verses' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'The Buried Giant' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'This is Going to Hurt: Secret Diaries of a Junior Doctor' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Educated: A Memoir' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Wild: From Lost to Found on the Pacific Crest Trail' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Hillbilly Elegy: A Memoir of a Family and Culture in Crisis' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Bird By Bird: Some Instructions on Writing and Life' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Eat Pray Love: One Woman's Search for Everything Across Italy, India and Indonesia' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Pretty Girls' to 'Mystery' due to tag 'Missing persons'
# Updated genre of book 'My Best Friend's Exorcism' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Piranesi' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'On Writing: A Memoir of the Craft' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Kafka on the Shore' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Yes Please' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Life of Pi' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Kitchen Confidential : Adventures in the Culinary Underbelly' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Turn Of The Screw' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Thinking in Pictures, Expanded Edition: My Life with Autism' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Things They Carried' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Winter's Tale' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Bossypants' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Anya's Ghost' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Let's Explore Diabetes with Owls' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Night Circus' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Just Kids' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'When Breath Becomes Air' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'What I Talk About When I Talk About Running' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Complete Maus' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Anthropocene Reviewed' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Invisible Life of Addie LaRue' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Horrorstör' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Greenlights' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Midnight Library' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Why Fish Don't Exist: A Story of Loss, Love, and the Hidden Order of Life' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Crying in H Mart' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Running With Scissors' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Every Heart a Doorway' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Is Everyone Hanging Out Without Me?' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Between Two Kingdoms: A Memoir of a Life Interrupted' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Can't Hurt Me: Master Your Mind and Defy the Odds' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'She Who Became the Sun' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Conjure Women' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Nothing to See Here' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Welcome to the Goddamn Ice Cube' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Rules of Magic' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Hunger' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Bunny' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Before the Coffee Gets Cold' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'They Called Us Enemy' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Barbarian Days: A Surfing Life' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Slewfoot: A Tale of Bewitchery' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Lovecraft Country' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Gender Queer' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Happiness Project' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'All's Well' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Nightbitch' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'This Time Tomorrow' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'When Women Were Dragons' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'The Cat Who Saved Books' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'I'm Glad My Mom Died' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Making of Prince of Persia' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Cartographers' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'What My Bones Know: A Memoir of Healing from Complex Trauma' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Tales from the Cafe' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Remarkably Bright Creatures' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Man's Search for Meaning' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Dead Romantics' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Lapvona' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'The Devil Takes You Home' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'How to Sell a Haunted House' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Ducks: Two Years in the Oil Sands' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Bliss Montage' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Beyond the Wand: The Magic and Mayhem of Growing Up a Wizard' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Finding Me' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Solito' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Weyward' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Silver in the Bone' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Family Lore' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Bad Cree' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Monstrilio' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Rouge' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Spare' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Friends, Lovers, and the Big Terrible Thing' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Wedding Witch' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Lone Women' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Camp Damascus' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Strong Female Character' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Seven Year Slip' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Nineteen Claws and a Black Bird: Stories' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Pageboy: A Memoir' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Paris: The Memoir' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'What the River Knows' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'A Child Called It: One Child's Courage to Survive' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Emily Wilde’s Map of the Otherlands' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Norwegian Wood' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Bride' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Chlorine' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'The Cemetery of Untold Stories' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'The Woman in Me' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Counting the Cost' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Sure, I'll Join Your Cult: A Memoir of Mental Illness and the Quest to Belong Anywhere' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Bullet Swallower' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'North Woods' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'A Short Walk Through a Wide World' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'When Among Crows' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'A Novel Love Story' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Before We Forget Kindness' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Diavola' to 'Fantasy' due to tag 'Supernatural'
# Updated genre of book 'Taste: My Life Through Food' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'The Book of Doors' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'The Husbands' to 'Fantasy' due to tag 'Magical Realism'
# Updated genre of book 'Down with the System: A Memoir' to 'Biography & Autobiography' due to tag 'Memoir'
# Updated genre of book 'Incidents Around the House' to 'Fantasy' due to tag 'Supernatural'
# Step 2: Genres updated successfully!
# Step 2: Cleaned books data has been successfully saved to new_updated_data.csv.
# Step 2: Unique genre tags have been saved to final_updated_genre_tags.csv.
